# %% [markdown]
# ---
# title: "Habits"
# author: "Linda Ding"
# format:
#     revealjs
# bibliography: reference.bib
# execute:
#     echo: true
#     code-fold: true
#     eval: true
#     code-summary: "Show code"
# ---
#
# ## Introduction
#
# This is the first slide.
#
# ![alt text](../slides/images/IMG-5122.jpg)
#
#
# ## Slide 2
#
# This is the second slide.
#
# ![alt text](../slides/images/unnamed.jpg)
#
#
# ## Slide 3
#
# ```{.python }
# #| echo: false
# #| code-fold: true
# #| code-summary: "expand for full code"
#
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.random.rand(77)
#
# plt.hist(x, bins=20, label='Random Data', color='pink', alpha=0.7)
#
# plt.xlabel('X')
# plt.ylabel('Frequency')
# plt.title('Histogram of Random Data')
# plt.legend()
#
# plt.show()
# ```
#
#
# ## Slide 4
#
# [@ghosal2020short]

# %%
#| echo: true
#| code-fold: true
#| code-summary: "expand for full code"

import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(77) 

plt.hist(x, bins=20, label='Random Data', color='pink', alpha=0.7)

plt.xlabel('X')
plt.ylabel('Frequency')
plt.title('Histogram of Random Data')
plt.legend()

plt.show()

# %% [markdown]
# ## Slide 5
